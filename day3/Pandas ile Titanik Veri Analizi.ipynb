# %% [markdown]
# ## Pandas ile Veri Analizi (Titanik)
#
# Titanik veri seti üzerinde Pandas ile veri analizi çalışması yapılmaktadır.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. Kütüphaneleri Yükle

# %%
import pandas as pd
import numpy as np

#veri görselleştirme
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Uyarıları kapat
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. Veri Setini Yükle

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E27C-4247
#
#  Directory of C:\Users\”mer\makineOgrenmesiBTK\day3
#
# 03.11.2024  20:34    <DIR>          .
# 03.11.2024  20:29    <DIR>          ..
# 03.11.2024  20:34    <DIR>          .ipynb_checkpoints
# 02.11.2024  14:43            55.966 corona_dat.csv
# 03.11.2024  20:32           579.476 Corona-Veri-G”rselleŸtirme.ipynb
# 03.11.2024  20:32         1.604.905 covid_19_data.mp4
# 02.11.2024  16:44           491.245 Pandas ile Titanik Veri Analizi.ipynb
# 02.11.2024  10:30            61.194 Titanic-Dataset.csv
#                5 File(s)      2.792.786 bytes
#                3 Dir(s)  45.138.423.808 bytes free

# %%
df=pd.read_csv("Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# SibSp (Sibling Spouse): gemide bulunan kardeş (sibling) ve eş (spouse) sayısını temsil eder. Yani bu değer, yolcunun gemideki aile bağlarını gösterir. Parch (Parent Child): yolcunun Titanik gemisindeki yolculuğu sırasında gemide bulunan ebeveyn (parent) ve çocuk (child) sayısını temsil eder. Fare: Bilet ücreti Embarked: Yolcunun bindiği liman

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Betimsel istatislikler
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000     891  891.000000      204
# unique         NaN         NaN         NaN     681         NaN      147
# top            NaN         NaN         NaN  347082         NaN  B96 B98
# freq           NaN         NaN         NaN       7         NaN        4
# mean     29.699118    0.523008    0.381594     NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
# bir katogoriye ait örnek sayısı
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# yolcu isimlerini listelemek istersek
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# birden fazla kolon secilceği zaman parantezde aranır
df[['Name','Age',"Sex"]]
# Out:
#                                                   Name   Age     Sex
# 0                              Braund, Mr. Owen Harris  22.0    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                               Heikkinen, Miss. Laina  26.0  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                             Allen, Mr. William Henry  35.0    male
# ..                                                 ...   ...     ...
# 886                              Montvila, Rev. Juozas  27.0    male
# 887                       Graham, Miss. Margaret Edith  19.0  female
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female
# 889                              Behr, Mr. Karl Howell  26.0    male
# 890                                Dooley, Mr. Patrick  32.0    male
#
# [891 rows x 3 columns]

# %%
df.Name.head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
# yaş sutunundaki max değer
df.Age.max()
# Out:
# 80.0

# %%
df.Age.min(),df.Age.mean(),df.Age.median()
# Out:
# (0.42, 29.69911764705882, 28.0)

# %%
df[df["Age"]==80]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
df[df["Age"]>60]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
# 252          253         0       1                  Stead, Mr. William Thomas
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 280          281         0       3                           Duane, Mr. Frank
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 438          439         0       1                          Fortune, Mr. Mark
# 456          457         0       1                  Millet, Mr. Francis Davis
# 483          484         1       3                     Turkula, Mrs. (Hedwig)
# 493          494         0       1                    Artagaveytia, Mr. Ramon
# 545          546         0       1               Nicholson, Mr. Arthur Ernest
# 555          556         0       1                         Wright, Mr. George
# 570          571         1       2                         Harris, Mr. George
# 625          626         0       1                      Sutton, Mr. Frederick
# 630          631         1       1       Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2                Mitchell, Mr. Henry Michael
# 745          746         0       1               Crosby, Capt. Edward Gifford
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
# 851          852         0       3                        Svensson, Mr. Johan
#
#         Sex   Age  SibSp  Parch       Ticket      Fare        Cabin Embarked
# 33     male  66.0      0      0   C.A. 24579   10.5000          NaN        S
# 54     male  65.0      0      1       113509   61.9792          B30        C
# 96     male  71.0      0      0     PC 17754   34.6542           A5        C
# 116    male  70.5      0      0       370369    7.7500          NaN        Q
# 170    male  61.0      0      0       111240   33.5000          B19        S
# 252    male  62.0      0      0       113514   26.5500          C87        S
# 275  female  63.0      1      0        13502   77.9583           D7        S
# 280    male  65.0      0      0       336439    7.7500          NaN        Q
# 326    male  61.0      0      0       345364    6.2375          NaN        S
# 438    male  64.0      1      4        19950  263.0000  C23 C25 C27        S
# 456    male  65.0      0      0        13509   26.5500          E38        S
# 483  female  63.0      0      0         4134    9.5875          NaN        S
# 493    male  71.0      0      0     PC 17609   49.5042          NaN        C
# 545    male  64.0      0      0          693   26.0000          NaN        S
# 555    male  62.0      0      0       113807   26.5500          NaN        S
# 570    male  62.0      0      0  S.W./PP 752   10.5000          NaN        S
# 625    male  61.0      0      0        36963   32.3208          D50        S
# 630    male  80.0      0      0        27042   30.0000          A23        S
# 672    male  70.0      0      0   C.A. 24580   10.5000          NaN        S
# 745    male  70.0      1      1    WE/P 5735   71.0000          B22        S
# 829  female  62.0      0      0       113572   80.0000          B28      NaN
# 851    male  74.0      0      0       347060    7.7750          NaN        S

# %%
len(df[df["Age"]>=60])
# Out:
# 26

# %%
# yaş ve ücret ortalaması 
df[['Age','Fare']].mean()
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
df[['Age','Fare']].min()
# Out:
# Age     0.42
# Fare    0.00
# dtype: float64

# %%
len(df[df['Fare']==0])
# Out:
# 15

# %%
df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# en küçöük yaştaki kişi hayatta kaldı mı
df[df['Age']==df['Age'].min()]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803  0.42      0      1   2625  8.5167   NaN        C

# %% [markdown]
# # Kategorik İşlemler
# ## value counts()

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Sex'].value_counts(normalize=True)
# Out:
# Sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64

# %%
df['Sex'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#CİNSİYETTE EKSİK VERİ VARMI
df.Sex.isnull().sum()
# Out:
# 0

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Embarked'].nunique()
# Out:
# 3

# %%
# dilimleme işlemleri 
df.iloc[0,]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
df.Age[0]
# Out:
# 22.0

# %%
df[["Name","Age"]][0:1]
# Out:
#                       Name   Age
# 0  Braund, Mr. Owen Harris  22.0

# %%
df[["Name","Age"]].head()
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0

# %%
df[["Name","Age"]].tail()
# Out:
#                                          Name   Age
# 886                     Montvila, Rev. Juozas  27.0
# 887              Graham, Miss. Margaret Edith  19.0
# 888  Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                     Behr, Mr. Karl Howell  26.0
# 890                       Dooley, Mr. Patrick  32.0

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# nameden age kadar age dahil sutunları al
df.loc[0:5,"Name":"Age"]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN

# %%
#name ve age sutunlarını al
df.loc[0:5,["Name","Age"]]
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0
# 5                                   Moran, Mr. James   NaN

# %% [markdown]
# ##  Sorgular (Sql gibi)

# %%
df[(df["Age"]>70) & (df["Survived"]==1)]["Name"]
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
df.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["Survived"].groupby(df["Sex"]).value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
df["Survived"].groupby(df["Sex"]).value_counts(normalize=True)
# Out:
# Sex     Survived
# female  1           0.742038
#         0           0.257962
# male    0           0.811092
#         1           0.188908
# Name: proportion, dtype: float64

# %%
df["Survived"].groupby(df["Sex"]).value_counts(normalize=True).plot.bar()
# Out:
# <Axes: xlabel='Sex,Survived'>

# %%
sns.barplot(x="Sex",y="Survived",data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#cinsiyete göre hayatta kalma 

sns.set(style="whitegrid")
sns.barplot(x="Sex",y="Survived",hue="Pclass",data=df,palette=["yellow","purple","blue"])
plt.show()

# %%
sns.barplot(y="Survived",hue="Sex",data=df,palette=["blue","pink"])
plt.show()

# %%
df[(df["Pclass"]==3) & (df["Sex"]=="female")]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 14            15         0       3
# 18            19         0       3
# ..           ...       ...     ...
# 863          864         0       3
# 875          876         1       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 8        2            347742  11.1333   NaN        S
# 10       1           PP 9549  16.7000    G6        S
# 14       0            350406   7.8542   NaN        S
# 18       0            345763  18.0000   NaN        S
# ..     ...               ...      ...   ...      ...
# 863      2          CA. 2343  69.5500   NaN        S
# 875      0              2667   7.2250   NaN        C
# 882      0              7552  10.5167   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 888      2        W./C. 6607  23.4500   NaN        S
#
# [144 rows x 12 columns]

# %%
len(df[(df["Pclass"]==3) & (df["Sex"]=="female")])
# Out:
# 144

# %%
df_secim=df[(df["Pclass"]==3) & (df["Sex"]=="female")]

# %%
df_secim
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 14            15         0       3
# 18            19         0       3
# ..           ...       ...     ...
# 863          864         0       3
# 875          876         1       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 8        2            347742  11.1333   NaN        S
# 10       1           PP 9549  16.7000    G6        S
# 14       0            350406   7.8542   NaN        S
# 18       0            345763  18.0000   NaN        S
# ..     ...               ...      ...   ...      ...
# 863      2          CA. 2343  69.5500   NaN        S
# 875      0              2667   7.2250   NaN        C
# 882      0              7552  10.5167   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 888      2        W./C. 6607  23.4500   NaN        S
#
# [144 rows x 12 columns]

# %%
df_secim["Survived"].value_counts(normalize=True)
# Out:
# Survived
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64

# %%
df[(df["Pclass"] == 3) & (df["Sex"] == "female")]["Survived"].value_counts(normalize=True).plot.bar()
plt.show()

# %%
df[["Survived","Sex"]].groupby(df["Pclass"]).value_counts(normalize=True)
# Out:
# Pclass  Survived  Sex
# 1       1         female    0.421296
#         0         male      0.356481
#         1         male      0.208333
#         0         female    0.013889
# 2       0         male      0.494565
#         1         female    0.380435
#                   male      0.092391
#         0         female    0.032609
# 3       0         male      0.610998
#                   female    0.146640
#         1         female    0.146640
#                   male      0.095723
# Name: proportion, dtype: float64

# %%
df[["Survived","Sex"]].groupby(df["Pclass"]).value_counts()
# Out:
# Pclass  Survived  Sex
# 1       1         female     91
#         0         male       77
#         1         male       45
#         0         female      3
# 2       0         male       91
#         1         female     70
#                   male       17
#         0         female      6
# 3       0         male      300
#                   female     72
#         1         female     72
#                   male       47
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,7))
sns.histplot(data=df,x="Age",hue="Survived",multiple="stack",kde=True,palette="pastel",bins=10,alpha=.5)
plt.title("Yas-Hayatta kalma grafiği")
plt.show()

# %%
sns.barplot(x='Sex',y='Survived',data=df,ci=None,palette=["pink","blue"])
for container in plt.gca().containers:
    labels=[f'{int(value.get_height()*100)}%' for value in container]
    plt.bar_label(container,labels=labels)
plt.xlabel("Cinsiyet")
plt.ylabel("Hayatta kalma oranı")
plt.title("Cinsiyete göre hayatta kalma")
plt.show()

# %%
df["Cinsiyet"]=df["Sex"].replace({"male":"e","female" : "k"})

# %%
df["Cinsiyet"]
# Out:
# 0      e
# 1      k
# 2      k
# 3      k
# 4      e
#       ..
# 886    e
# 887    k
# 888    k
# 889    e
# 890    e
# Name: Cinsiyet, Length: 891, dtype: object

# %%
df[["Sex","Age"]].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked Cinsiyet
# 0        0         A/5 21171   7.2500   NaN        S        e
# 1        0          PC 17599  71.2833   C85        C        k
# 2        0  STON/O2. 3101282   7.9250   NaN        S        k
# 3        0            113803  53.1000  C123        S        k
# 4        0            373450   8.0500   NaN        S        e
# ..     ...               ...      ...   ...      ...      ...
# 886      0            211536  13.0000   NaN        S        e
# 887      0            112053  30.0000   B42        S        k
# 888      2        W./C. 6607  23.4500   NaN        S        k
# 889      0            111369  30.0000  C148        C        e
# 890      0            370376   7.7500   NaN        Q        e
#
# [891 rows x 13 columns]

# %%
#en yaşlı on kişi
df.nlargest(10,"Age")[["Name","Age"]]
# Out:
#                                      Name   Age
# 630  Barkworth, Mr. Algernon Henry Wilson  80.0
# 851                   Svensson, Mr. Johan  74.0
# 96              Goldschmidt, Mr. George B  71.0
# 493               Artagaveytia, Mr. Ramon  71.0
# 116                  Connors, Mr. Patrick  70.5
# 672           Mitchell, Mr. Henry Michael  70.0
# 745          Crosby, Capt. Edward Gifford  70.0
# 33                  Wheadon, Mr. Edward H  66.0
# 54         Ostby, Mr. Engelhart Cornelius  65.0
# 280                      Duane, Mr. Frank  65.0

# %%
# sıralama asc
df.sort_values(by="Age", ascending=False)[["Name","Age"]].head(10)
# Out:
#                                      Name   Age
# 630  Barkworth, Mr. Algernon Henry Wilson  80.0
# 851                   Svensson, Mr. Johan  74.0
# 493               Artagaveytia, Mr. Ramon  71.0
# 96              Goldschmidt, Mr. George B  71.0
# 116                  Connors, Mr. Patrick  70.5
# 672           Mitchell, Mr. Henry Michael  70.0
# 745          Crosby, Capt. Edward Gifford  70.0
# 33                  Wheadon, Mr. Edward H  66.0
# 54         Ostby, Mr. Engelhart Cornelius  65.0
# 280                      Duane, Mr. Frank  65.0

# %%
df["Age"].isnull().sum()
# Out:
# 177

# %%
df.sort_values(by="Age", ascending=False)[["Name","Age"]].tail(178)
# Out:
#                                          Name   Age
# 803           Thomas, Master. Assad Alexander  0.42
# 5                            Moran, Mr. James   NaN
# 17               Williams, Mr. Charles Eugene   NaN
# 19                    Masselmani, Mrs. Fatima   NaN
# 26                    Emir, Mr. Farred Chehab   NaN
# ..                                        ...   ...
# 859                          Razi, Mr. Raihed   NaN
# 863         Sage, Miss. Dorothy Edith "Dolly"   NaN
# 868               van Melkebeke, Mr. Philemon   NaN
# 878                        Laleff, Mr. Kristo   NaN
# 888  Johnston, Miss. Catherine Helen "Carrie"   NaN
#
# [178 rows x 2 columns]
