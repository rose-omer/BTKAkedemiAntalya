# %% [markdown]
# ## Finans Verileri İle Calışmak
# ![image.png](attachment:1db1fe64-6918-45ce-b1c1-201209f93c5e.png)

# %%
#!pip install yfinance

# %%
import yfinance as yf

# %%
google=yf.Ticker("GOOG")
df=google.history(period="1d",start="2024-01-01",end="2024-10-31")

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-01-02 00:00:00-05:00  139.258020  140.270533  137.402576  139.218109
# 2024-01-03 00:00:00-05:00  138.260461  140.744351  138.090864  140.016144
# 2024-01-04 00:00:00-05:00  139.507407  140.290472  137.671903  137.701828
# 2024-01-05 00:00:00-05:00  138.013070  138.469940  136.514751  137.053421
# 2024-01-08 00:00:00-05:00  137.661914  140.295446  137.542213  140.185715
# ...                               ...         ...         ...         ...
# 2024-10-24 00:00:00-04:00  164.589996  165.050003  162.770004  164.529999
# 2024-10-25 00:00:00-04:00  165.365005  167.399994  165.229996  166.990005
# 2024-10-28 00:00:00-04:00  170.589996  170.606003  165.789993  168.339996
# 2024-10-29 00:00:00-04:00  169.384995  171.860001  168.660004  171.139999
# 2024-10-30 00:00:00-04:00  182.410004  183.789993  175.744995  176.139999
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
df.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df["Close"].plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df2=yf.download(["NVDA",
                 "GOOG",
                 "TSLA",
                 "AAPL",
                 "MSFT"],start="2024-01-01",end="2024-11-7")
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
df2["Close"].plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df3=yf.download(["NVDA",],start="2024-01-01",end="2024-11-7")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df3["Close"].plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>
