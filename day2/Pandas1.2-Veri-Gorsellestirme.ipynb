# %% [markdown]
# ![WhatsApp Görsel 2024-10-27 saat 16.12.50_e3e8d576.jpg](attachment:7df5af30-5734-4a0c-82ce-1ed60b4ca62d.jpg)

# %% [markdown]
# Pandas İle Veri Analzi
# Pandas ile uygulamalı veir analizi
# # 1.Kütüphaneleri Yükle

# %%
import pandas as pd
import numpy as np
#veriş görselleştirme
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Veriyi Yükle

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E27C-4247
#
#  Directory of C:\Users\”mer\makineOgrenmesiBTK\hafta1
#
# 27.10.2024  16:05    <DIR>          .
# 26.10.2024  11:33    <DIR>          ..
# 26.10.2024  11:39               282 .hafta1.1.ipynb.layout
# 27.10.2024  16:03    <DIR>          .ipynb_checkpoints
# 26.10.2024  15:20            20.097 hafta1.1.ipynb
# 27.10.2024  15:28           330.195 hafta1.2.ipynb
# 27.10.2024  15:28                29 notlar.csv
# 27.10.2024  15:28                40 notlar.txt
# 27.10.2024  15:28                29 notlar2.csv
# 27.10.2024  16:05             1.192 pandas1.2.ipynb
# 27.10.2024  15:59            95.770 pandas1.ipynb
# 27.10.2024  16:04            61.194 Titanic-Dataset.csv
#                9 File(s)        508.828 bytes
#                3 Dir(s)  47.268.556.800 bytes free

# %%
df=pd.read_csv('Titanic-Dataset.csv')

# %% [markdown]
# # 3. HEAD (Keşifsel Veri Analizi)
# head(), tail() metotları ile ilk ve son 5 veri arasını görebilirsiniz

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# SibSp (Sibling Spouse): gemide bulunan kardeş (sibling) ve eş (spouse) sayısını temsil eder. Yani bu değer, yolcunun gemideki aile bağlarını gösterir. Parch (Parent Child): yolcunun Titanik gemisindeki yolculuğu sırasında gemide bulunan ebeveyn (parent) ve çocuk (child) sayısını temsil eder. Fare: Bilet ücreti Embarked: Yolcunun bindiği liman

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#betimsel istatistikler
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...
