# %%
import pandas as pd

# %%
#pip install lxml

# %% [markdown]
# # HTML den okuma

# %%
df=pd.read_html("https://tr.wikipedia.org/wiki/D%C3%BCnyan%C4%B1n_en_zenginleri_listesi")[2]
df
# Out:
#    Sıra                      İsim       Servet  Yaş  \
# 0     1  Bernard Arnault & ailesi  $233 milyar   75
# 1     2                 Elon Musk  $195 milyar   52
# 2     3                Jeff Bezos  $194 milyar   60
# 3     4           Mark Zuckerberg  $177 milyar   39
# 4     5             Larry Ellison  $141 milyar   79
# 5     6            Warren Buffett  $133 milyar   93
# 6     7                Bill Gates  $128 milyar   68
# 7     8             Steve Ballmer  $121 milyar   68
# 8     9             Mukesh Ambani  $116 milyar   67
# 9    10                Larry Page  $114 milyar   51
#
#                        Uyruk     Servetin Kaynağı
# 0                     Fransa                 LVMH
# 1  ABD  Kanada  Güney Afrika        Tesla, SpaceX
# 2                        ABD               Amazon
# 3                        ABD           Meta, Inc.
# 4                        ABD   Oracle Corporation
# 5                        ABD   Berkshire Hathaway
# ...

# %%
df["İsim"]
# Out:
# 0    Bernard Arnault & ailesi
# 1                   Elon Musk
# 2                  Jeff Bezos
# 3             Mark Zuckerberg
# 4               Larry Ellison
# 5              Warren Buffett
# 6                  Bill Gates
# 7               Steve Ballmer
# 8               Mukesh Ambani
# 9                  Larry Page
# Name: İsim, dtype: object

# %% [markdown]
# # Web den CSV dosyası Okuma

# %%
# CSV olarak kaydetme
df.to_csv('Dunyanin_en_zenginleri.csv')

# %%
# CSV olarak OKUMA
df=pd.read_csv('Dunyanin_en_zenginleri.csv')
df
# Out:
#    Unnamed: 0  Sıra                      İsim       Servet  Yaş  \
# 0           0     1  Bernard Arnault & ailesi  $233 milyar   75
# 1           1     2                 Elon Musk  $195 milyar   52
# 2           2     3                Jeff Bezos  $194 milyar   60
# 3           3     4           Mark Zuckerberg  $177 milyar   39
# 4           4     5             Larry Ellison  $141 milyar   79
# 5           5     6            Warren Buffett  $133 milyar   93
# 6           6     7                Bill Gates  $128 milyar   68
# 7           7     8             Steve Ballmer  $121 milyar   68
# 8           8     9             Mukesh Ambani  $116 milyar   67
# 9           9    10                Larry Page  $114 milyar   51
#
#                        Uyruk     Servetin Kaynağı
# 0                     Fransa                 LVMH
# 1  ABD  Kanada  Güney Afrika        Tesla, SpaceX
# 2                        ABD               Amazon
# 3                        ABD           Meta, Inc.
# ...

# %% [markdown]
# # Excel okuma ve kaydetme

# %%
# Excel olarak kaydetme
df.to_excel('Dunyanin_en_zenginleri.xlsx',index=False)

# %%
# Excel olarak okuma
data2=pd.read_excel('Dunyanin_en_zenginleri.xlsx')
data2
# Out:
#    Unnamed: 0  Sıra                      İsim       Servet  Yaş  \
# 0           0     1  Bernard Arnault & ailesi  $233 milyar   75
# 1           1     2                 Elon Musk  $195 milyar   52
# 2           2     3                Jeff Bezos  $194 milyar   60
# 3           3     4           Mark Zuckerberg  $177 milyar   39
# 4           4     5             Larry Ellison  $141 milyar   79
# 5           5     6            Warren Buffett  $133 milyar   93
# 6           6     7                Bill Gates  $128 milyar   68
# 7           7     8             Steve Ballmer  $121 milyar   68
# 8           8     9             Mukesh Ambani  $116 milyar   67
# 9           9    10                Larry Page  $114 milyar   51
#
#                        Uyruk     Servetin Kaynağı
# 0                     Fransa                 LVMH
# 1  ABD  Kanada  Güney Afrika        Tesla, SpaceX
# 2                        ABD               Amazon
# 3                        ABD           Meta, Inc.
# ...

# %%
df=pd.read_csv("https://www.stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2023-financial-year-provisional/Download-data/annual-enterprise-survey-2023-financial-year-provisional.csv")

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# # Clipboard datayı okumak
# ### Altaki değerleri kopyala
#
# df=pd.read_clipboard()
#
# df.to_csv('Dunya_nufusu.csv',index=False)
#
# ### ondan sonra calıştırSıra	İsim	Uyruk
# 1	Jeff Bezos	ABD
# 2	Bill Gates	ABD
# 3	Bernard Arnault ve ailesi	Fransa
# 4	Warren BuffettBDt
# 	ABD

# %%
df=pd.read_clipboard()
df
# Out:
#    Sıra                       İsim   Uyruk
# 0     1                 Jeff Bezos     ABD
# 1     2                 Bill Gates     ABD
# 2     3  Bernard Arnault ve ailesi  Fransa
# 3     4             Warren Buffett     ABD

# %%
df.to_csv('Dunya_nufusu.csv',index=False)
